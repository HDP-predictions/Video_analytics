# %%
import numpy as np
#import numpy as np
import glob
from imageio import imread
import pandas as pd
import cv2

# %%
pathExcel = '/part4/fps10Videos/'
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
data_k = pd.read_excel(pathExcel+'video_tags.xlsx', sheet_name='Site2')
data_m = pd.read_excel(pathExcel+'video_tags.xlsx')

# %%
data_k
# Out:
#            UHID                                      Video (Title)  \
# 0     191001977  NEO102.stream_720p_2020-01-21-07.57.03.617-UTC...
# 1     191001977  NEO102.stream_720p_2020-01-21-08.14.13.220-UTC...
# 2     191001977  NEO102.stream_720p_2020-01-21-08.14.13.220-UTC...
# 3     191001977  NEO102.stream_720p_2020-01-21-08.14.13.220-UTC...
# 4     191001977  NEO102.stream_720p_2020-01-21-08.14.13.220-UTC...
# ...         ...                                                ...
# 1642  200201148  NEOTINY102.stream_720p_2020-02-26-11.34.04.078...
# 1643  200201148  NEOTINY102.stream_720p_2020-02-26-11.38.01.676...
# 1644  200201148  NEOTINY102.stream_720p_2020-02-27-04.29.39.874...
# 1645  200201148  NEOTINY102.stream_720p_2020-02-27-04.29.39.874...
# 1646  200201148  NEOTINY102.stream_720p_2020-02-27-06.49.15.306...
#
#       Total Duration of video file (min.sec) From (min.sec) To (min.sec)  \
# 0                                      13.57           5.20         5.57
# ...

# %%
videos_k=pd.DataFrame(data_k['Video (Title)'].unique())

# %%
videos_m=pd.DataFrame(data_m['Video (Title)'].unique())

# %%
videos_k
# Out:
#                                                      0
# 0    NEO102.stream_720p_2020-01-21-07.57.03.617-UTC...
# 1    NEO102.stream_720p_2020-01-21-08.14.13.220-UTC...
# 2    NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...
# 3    NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...
# 4    NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...
# ..                                                 ...
# 928  NEOTINY102.stream_720p_2020-02-26-08.43.21.065...
# 929  NEOTINY102.stream_720p_2020-02-26-11.34.04.078...
# 930  NEOTINY102.stream_720p_2020-02-26-11.38.01.676...
# 931  NEOTINY102.stream_720p_2020-02-27-04.29.39.874...
# 932  NEOTINY102.stream_720p_2020-02-27-06.49.15.306...
#
# [933 rows x 1 columns]

# %%
videos_total=videos_k.append(videos_m)

# %%
videos_total
# Out:
#                                                      0
# 0    NEO102.stream_720p_2020-01-21-07.57.03.617-UTC...
# 1    NEO102.stream_720p_2020-01-21-08.14.13.220-UTC...
# 2    NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...
# 3    NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...
# 4    NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...
# ..                                                 ...
# 112  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...
# 113  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...
# 114  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...
# 115  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...
# 116  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...
#
# [1050 rows x 1 columns]

# %%
videos_total['Frames']=pd.np.nan
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   """Entry point for launching an IPython kernel.

# %%
videos_total
# Out:
#                                                      0  Frames
# 0    NEO102.stream_720p_2020-01-21-07.57.03.617-UTC...     NaN
# 1    NEO102.stream_720p_2020-01-21-08.14.13.220-UTC...     NaN
# 2    NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...     NaN
# 3    NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...     NaN
# 4    NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...     NaN
# ..                                                 ...     ...
# 112  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...     NaN
# 113  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...     NaN
# 114  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...     NaN
# 115  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...     NaN
# 116  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...     NaN
#
# [1050 rows x 2 columns]

# %%
l = videos_total[0]

# %%
l
# Out:
# 0      NEO102.stream_720p_2020-01-21-07.57.03.617-UTC...
# 1      NEO102.stream_720p_2020-01-21-08.14.13.220-UTC...
# 2      NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...
# 3      NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...
# 4      NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...
#                              ...
# 112    NEOTINY104.stream_720p_2020-03-31-06.45.48.422...
# 113    NEOTINY104.stream_720p_2020-03-31-06.45.48.422...
# 114    NEOTINY104.stream_720p_2020-03-31-06.45.48.422...
# 115    NEOTINY104.stream_720p_2020-03-31-06.45.48.422...
# 116    NEOTINY104.stream_720p_2020-03-31-06.45.48.422...
# Name: 0, Length: 1050, dtype: object

# %%
pathMN = '/part1/MotiNagarVideoData/'
pathKal= '/part2/KalawatiVideoData/'
pathWowza = '/part4/Wowza/'

# %%
import os

# %%
MNcheck=os.listdir(pathMN)

# %%
Kalcheck=os.listdir(pathKal)

# %%
Wowzacheck=os.listdir(pathWowza)

# %%
MNcheck
# Out:
# ['.classificationScript.py.swp',
#  'NEO109.stream_2019-12-27-09.26.51.821-UTC_17.mp4',
#  'NEOTINY104.stream_720p_2020-02-26-21.31.29.705-UTC_3.mp4',
#  'NEOTINY104.stream_720p_2020-02-26-14.51.02.381-UTC_0.mp4',
#  'NEOTINY104.stream_720p_2020-02-26-21.31.29.705-UTC_5.mp4',
#  'NEOTINY104.stream_720p_2020-02-26-14.44.08.508-UTC_0.mp4',
#  'NEO121.stream',
#  'NEOTINY104.stream_720p_2020-02-26-06.41.31.944-UTC_1.mp4',
#  'NEO121.stream_2020-01-08-07.14.52.543-UTC_0.mp4',
#  'NEOTINY104.stream_720p_2020-02-26-16.14.35.211-UTC_0.mp4',
#  'NEO109.stream_2019-12-27-09.26.51.821-UTC_12.mp4',
#  'NEO109.stream_2019-12-23-12.41.36.889-UTC_2.mp4',
#  'NEOTINY104.stream_720p_2020-02-26-18.52.24.298-UTC_0.mp4',
#  'NEO109.stream_2019-12-23-12.41.36.889-UTC_6.mp4',
#  'NEO102.stream',
#  'NEO109.stream_2019-12-27-09.26.51.821-UTC_18.mp4',
#  'NEOTINY104.stream_720p_2020-02-26-17.09.02.025-UTC_0.mp4',
#  'NEO109.stream_2019-12-27-09.26.51.821-UTC_19.mp4',
# ...

# %%
for i in range(len(videos_total)):
    
    if (videos_total[0].iloc[i] in MNcheck):
        cap = cv2.VideoCapture(pathMN+str(videos_total[0].iloc[i]))
        length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        videos_total['Frames'].iloc[i]=length
    elif (videos_total[0].iloc[i] in Kalcheck):
        cap = cv2.VideoCapture(pathKal+str(videos_total[0].iloc[i]))
        length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        videos_total['Frames'].iloc[i]=length
    elif (videos_total[0].iloc[i] in Wowzacheck):
        cap = cv2.VideoCapture(pathWowza+str(videos_total[0].iloc[i]))
        length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        videos_total['Frames'].iloc[i]=length
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
videos_total['Frames'].sum()
# Out:
# 36830790.0

# %%
videos_total
# Out:
#                                                      0    Frames
# 0    NEO102.stream_720p_2020-01-21-07.57.03.617-UTC...   24360.0
# 1    NEO102.stream_720p_2020-01-21-08.14.13.220-UTC...  107310.0
# 2    NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...  105225.0
# 3    NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...  107850.0
# 4    NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...  107895.0
# ..                                                 ...       ...
# 112  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...   56340.0
# 113  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...   53925.0
# 114  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...   54000.0
# 115  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...   54015.0
# 116  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...   31260.0
#
# [1050 rows x 2 columns]

# %%
data_total=pd.concat([data_k, data_m])

# %%
data_total['Frames']=pd.np.nan
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   """Entry point for launching an IPython kernel.

# %%
def time_sec(x):
    try:        
        x = str(x)
        minute = int(x.split('.')[0])*60
        sec = int(x.split('.')[1])
        time = minute+sec
        return time
        
    except:
        pass

# %%
data_total['from_sec'] = data_total['From (min.sec)'].apply(time_sec)

# %%
data_total['to_sec'] = data_total['To (min.sec)'].apply(time_sec)

# %%
data_total['sec'] = data_total['to_sec'] - data_total['from_sec']

# %%
data_total
# Out:
#                 UHID                                      Video (Title)  \
# 0          191001977  NEO102.stream_720p_2020-01-21-07.57.03.617-UTC...
# 1          191001977  NEO102.stream_720p_2020-01-21-08.14.13.220-UTC...
# 2          191001977  NEO102.stream_720p_2020-01-21-08.14.13.220-UTC...
# 3          191001977  NEO102.stream_720p_2020-01-21-08.14.13.220-UTC...
# 4          191001977  NEO102.stream_720p_2020-01-21-08.14.13.220-UTC...
# ..               ...                                                ...
# 495  RSHI.0000024482  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...
# 496  RSHI.0000024482  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...
# 497  RSHI.0000024482  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...
# 498  RSHI.0000024482  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...
# 499  RSHI.0000024482  NEOTINY104.stream_720p_2020-03-31-06.45.48.422...
#
#      Total Duration of video file (min.sec) From (min.sec) To (min.sec)  \
# ...

# %%
from moviepy.editor import *

# %%
diaper=data_total[data_total['Label']=='Diaper_change']

# %%
len(diaper)
# Out:
# 63

# %%
diaper['sec'].mean()
# Out:
# 49.34920634920635

# %%
diaper['sec'].std()
# Out:
# 24.822699503685765

# %%
for i in range(len(diaper)):
    #try:
    if (diaper['Video (Title)'].iloc[i] in MNcheck):
        video = VideoFileClip(pathMN+str(diaper['Video (Title)'].iloc[i])).subclip(diaper['from_sec'].iloc[i],diaper['to_sec'].iloc[i])
        #cap = cv2.VideoCapture(pathMN+str(videos_total[0].iloc[i]))
        length = int(video.fps * video.duration)
        diaper['Frames'].iloc[i]=length
    elif (diaper['Video (Title)'].iloc[i] in Kalcheck):
        video = VideoFileClip(pathKal+str(diaper['Video (Title)'].iloc[i])).subclip(diaper['from_sec'].iloc[i],diaper['to_sec'].iloc[i])
        #cap = cv2.VideoCapture(pathMN+str(videos_total[0].iloc[i]))
        length = int(video.fps * video.duration)
        diaper['Frames'].iloc[i]=length
    elif (diaper['Video (Title)'].iloc[i] in Wowzacheck):
        video = VideoFileClip(pathWowza+str(diaper['Video (Title)'].iloc[i])).subclip(diaper['from_sec'].iloc[i],diaper['to_sec'].iloc[i])
        #cap = cv2.VideoCapture(pathMN+str(videos_total[0].iloc[i]))
        length = int(video.fps * video.duration)
        diaper['Frames'].iloc[i]=length
#except:
#        continue

# %%
diaper
# Out:
#                  UHID                                      Video (Title)  \
# 0           191001977  NEO102.stream_720p_2020-01-21-07.57.03.617-UTC...
# 18          200100035  NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...
# 42          200100035  NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...
# 111         200100035  NEO101.stream_720p_2020-01-06-19.00.26.977-UTC...
# 139         200100035  NEO101.stream_720p_2020-01-07-03.13.15.054-UTC...
# 167         200100035  NEO101.stream_720p_2020-01-07-16.57.58.404-UTC...
# 183         200100035  NEO101.stream_720p_2020-01-08-09.06.29.627-UTC...
# 200         200100035  NEO101.stream_720p_2020-01-08-11.57.57.298-UTC...
# 219         200100035  NEO101.stream_720p_2020-01-08-17.24.58.709-UTC...
# 235         200100035  NEO101.stream_720p_2020-01-08-19.26.40.027-UTC...
# 260         200100035  NEO101.stream_720p_2020-01-09-03.39.09.292-UTC...
# 315         200100035  NEO101.stream_720p_2020-01-10-12.11.21.560-UTC...
# ...

# %%
diaper['Frames'].sum()
# Out:
# 93270.0

# %%
feeding=data_total[data_total['Label']=='Feeding']

# %%
len(feeding)
# Out:
# 108

# %%
feeding['sec'].mean()
# Out:
# 108.87037037037037

# %%
feeding['sec'].std()
# Out:
# 55.54018375083483

# %%
for i in range(len(feeding)):
    try:
        if (feeding['Video (Title)'].iloc[i] in MNcheck):
            video = VideoFileClip(pathMN+str(feeding['Video (Title)'].iloc[i])).subclip(feeding['from_sec'].iloc[i],feeding['to_sec'].iloc[i])
            #cap = cv2.VideoCapture(pathMN+str(videos_total[0].iloc[i]))
            length = int(video.fps * video.duration)
            feeding['Frames'].iloc[i]=length
        elif (feeding['Video (Title)'].iloc[i] in Kalcheck):
            video = VideoFileClip(pathKal+str(feeding['Video (Title)'].iloc[i])).subclip(feeding['from_sec'].iloc[i],feeding['to_sec'].iloc[i])
            #cap = cv2.VideoCapture(pathMN+str(videos_total[0].iloc[i]))
            length = int(video.fps * video.duration)
            feeding['Frames'].iloc[i]=length
        elif (feeding['Video (Title)'].iloc[i] in Wowzacheck):
            video = VideoFileClip(pathWowza+str(feeding['Video (Title)'].iloc[i])).subclip(feeding['from_sec'].iloc[i],feeding['to_sec'].iloc[i])
            #cap = cv2.VideoCapture(pathMN+str(videos_total[0].iloc[i]))
            length = int(video.fps * video.duration)
            feeding['Frames'].iloc[i]=length
    except:
        continue

# %%
feeding
# Out:
#                  UHID                                      Video (Title)  \
# 1           191001977  NEO102.stream_720p_2020-01-21-08.14.13.220-UTC...
# 13          200100035  NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...
# 29          200100035  NEO101.stream_720p_2020-01-06-13.01.28.782-UTC...
# 53          200100035  NEO101.stream_720p_2020-01-06-17.59.06.817-UTC...
# 68          200100035  NEO101.stream_720p_2020-01-06-19.00.26.977-UTC...
# 73          200100035  NEO101.stream_720p_2020-01-06-19.00.26.977-UTC...
# 109         200100035  NEO101.stream_720p_2020-01-06-19.00.26.977-UTC...
# 135         200100035  NEO101.stream_720p_2020-01-07-03.13.15.054-UTC...
# 149         200100035  NEO101.stream_720p_2020-01-07-09.27.22.054-UTC...
# 158         200100035  NEO101.stream_720p_2020-01-07-11.01.12.817-UTC...
# 177         200100035  NEO101.stream_720p_2020-01-08-06.18.48.826-UTC...
# 192         200100035  NEO101.stream_720p_2020-01-08-11.57.57.298-UTC...
# ...

# %%
video = VideoFileClip(pathKal+'NEO102.stream_720p_2020-01-17-11.24.55.893-UTC_4.mp4')
#cap = cv2.VideoCapture(pathMN+str(videos_total[0].iloc[i]))
fps= int(video.fps)

#feeding['Frames'].iloc[i]=length

# %%
missing=fps*181

# %%
feeding['Frames'].sum()+missing
# Out:
# 352740.0

# %%
patting=data_total[data_total['Label']=='Patting']

# %%
len(patting)
# Out:
# 221

# %%
patting['sec'].mean()
# Out:
# 24.90950226244344

# %%
patting['sec'].std()
# Out:
# 25.80611185933646

# %%
for i in range(len(patting)):
    #try:
    if (patting['Video (Title)'].iloc[i] in MNcheck):
        video = VideoFileClip(pathMN+str(patting['Video (Title)'].iloc[i])).subclip(patting['from_sec'].iloc[i],patting['to_sec'].iloc[i])
        #cap = cv2.VideoCapture(pathMN+str(videos_total[0].iloc[i]))
        length = int(video.fps * video.duration)
        patting['Frames'].iloc[i]=length
    elif (patting['Video (Title)'].iloc[i] in Kalcheck):
        video = VideoFileClip(pathKal+str(patting['Video (Title)'].iloc[i])).subclip(patting['from_sec'].iloc[i],patting['to_sec'].iloc[i])
        #cap = cv2.VideoCapture(pathMN+str(videos_total[0].iloc[i]))
        length = int(video.fps * video.duration)
        patting['Frames'].iloc[i]=length
    elif (patting['Video (Title)'].iloc[i] in Wowzacheck):
        video = VideoFileClip(pathWowza+str(patting['Video (Title)'].iloc[i])).subclip(patting['from_sec'].iloc[i],patting['to_sec'].iloc[i])
        #cap = cv2.VideoCapture(pathMN+str(videos_total[0].iloc[i]))
        length = int(video.fps * video.duration)
        patting['Frames'].iloc[i]=length
#except:
#        continue

# %%
patting['Frames'].sum()
# Out:
# 165150.0

# %%
relevant=pd.concat([diaper, feeding, patting])

# %%
relevant['sec'].mean()
# Out:
# 51.96938775510204

# %%
relevant['sec'].std()
# Out:
# 51.24305536263285

# %%
videos_total['Duration']=pd.np.nan

# %%
for i in range(len(videos_total)):
    
    if (videos_total[0].iloc[i] in MNcheck):
        clip = VideoFileClip(pathMN+str(videos_total[0].iloc[i]))
        length = clip.duration
        videos_total['Duration'].iloc[i]=length
    elif (videos_total[0].iloc[i] in Kalcheck):
        clip = VideoFileClip(pathKal+str(videos_total[0].iloc[i]))
        length = clip.duration
        videos_total['Duration'].iloc[i]=length
    elif (videos_total[0].iloc[i] in Wowzacheck):
        clip = VideoFileClip(pathWowza+str(videos_total[0].iloc[i]))
        length = clip.duration
        videos_total['Duration'].iloc[i]=length

# %%
videos_total[0].iloc[0]
# Out:
# 'NEO102.stream_720p_2020-01-21-07.57.03.617-UTC_1.mp4'

# %%
videos_total['Duration'].sum()
# Out:
# 1264274.2799999998

# %%
data_k = pd.read_excel('video_tags.xlsx', sheet_name='Site2')
data_m = pd.read_excel('video_tags.xlsx')

# %%
data_total=pd.concat([data_k, data_m])

# %%
data_total['Frames']=pd.np.nan

# %%
data_total['from_sec'] = data_total['From (min.sec)'].apply(time_sec)

# %%
data_total['to_sec'] = data_total['To (min.sec)'].apply(time_sec)

# %%
data_total['sec'] = data_total['to_sec'] - data_total['from_sec']

# %%
diaper=data_total[data_total['Label']=='Diaper_change']

# %%
len(diaper)
# Out:
# 63

# %%
feeding=data_total[data_total['Label']=='Feeding']

# %%
len(feeding)
# Out:
# 108

# %%
patting=data_total[data_total['Label']=='Patting']

# %%
len(patting)
# Out:
# 221

# %%
other=data_total[data_total['Label']=='Other']

# %%
len(other)
# Out:
# 876

# %%
for i in range(len(other)):
    #try:
    if (other['Video (Title)'].iloc[i] in MNcheck):
        video = VideoFileClip(pathMN+str(other['Video (Title)'].iloc[i])).subclip(other['from_sec'].iloc[i],other['to_sec'].iloc[i])
        #cap = cv2.VideoCapture(pathMN+str(videos_total[0].iloc[i]))
        length = int(video.fps * video.duration)
        other['Frames'].iloc[i]=length
    elif (other['Video (Title)'].iloc[i] in Kalcheck):
        video = VideoFileClip(pathKal+str(other['Video (Title)'].iloc[i])).subclip(other['from_sec'].iloc[i],other['to_sec'].iloc[i])
        #cap = cv2.VideoCapture(pathMN+str(videos_total[0].iloc[i]))
        length = int(video.fps * video.duration)
        other['Frames'].iloc[i]=length
    elif (other['Video (Title)'].iloc[i] in Wowzacheck):
        video = VideoFileClip(pathWowza+str(other['Video (Title)'].iloc[i])).subclip(other['from_sec'].iloc[i],other['to_sec'].iloc[i])
        #cap = cv2.VideoCapture(pathMN+str(videos_total[0].iloc[i]))
        length = int(video.fps * video.duration)
        other['Frames'].iloc[i]=length
#except:
#        continue

# %%
other['Frames'].sum()
# Out:
# 967680.0
